# %%
import pandas as pd

imgs = pd.read_csv('data/img.csv')

imgs.head()
# Out:
#     depth   col1   col2   col3   col4   col5   col6   col7   col8   col9  ...  \
# 0  9000.1  224.0  224.0  224.0  224.0  224.0  224.0  224.0  224.0  224.0  ...
# 1  9000.2  224.0  224.0  224.0  224.0  224.0  224.0  224.0  224.0  224.0  ...
# 2  9000.3  224.0  224.0  224.0  224.0  224.0  224.0  224.0  224.0  224.0  ...
# 3  9000.4  224.0  224.0  224.0  224.0  224.0  224.0  224.0  224.0  224.0  ...
# 4  9000.5  224.0  224.0  224.0  224.0  224.0  224.0  224.0  224.0  224.0  ...
#
#    col191  col192  col193  col194  col195  col196  col197  col198  col199  \
# 0   224.0   225.0   226.0   225.0   224.0   223.0   221.0   220.0   217.0
# 1   224.0   225.0   226.0   225.0   224.0   223.0   222.0   221.0   219.0
# 2   224.0   225.0   226.0   226.0   225.0   224.0   224.0   223.0   223.0
# 3   224.0   225.0   226.0   226.0   225.0   225.0   225.0   225.0   225.0
# 4   225.0   224.0   223.0   223.0   224.0   224.0   225.0   225.0   225.0
#
#    col200
# 0   217.0
# 1   219.0
# 2   223.0
# ...

# %%
imgs.shape
# Out:
# (5461, 201)

# %%
import matplotlib.pyplot as plt

im = imgs.iloc[:-1, 1:]

plt.imshow(im, aspect='auto', cmap='inferno')
plt.show()

# %% [markdown]
# # Resized image

# %%
import cv2

height = int(im.shape[0])
new_size = (150, height)

resized_image = cv2.resize(im.to_numpy(), new_size, interpolation=cv2.INTER_AREA)

plt.imshow(resized_image, aspect='auto', cmap='inferno')

# %%
resized_image.shape
# Out:
# (2730, 150)

# %%
im.shape
# Out:
# (5460, 200)

# %%
import numpy as np

pixels = np.random.randint(0, 256, (5460, 200), dtype=np.uint8)
depths = np.arange(9000.1, 9546.0 + 0.1, 0.1)

df = pd.DataFrame(pixels, columns=[f'col{i}' for i in range(1, 201)])
df.insert(0, 'depth', depths)
df.loc[5460] = np.nan

# %%
import matplotlib.pyplot as plt

plt.imshow(pixels, aspect='auto', cmap='inferno')
plt.show()

# %%
from skimage.transform import resize
bottle_resized = resize(imgs.to_numpy(), (imgs.shape[0], 150))

plt.imshow(bottle_resized, aspect='auto', cmap='inferno')
